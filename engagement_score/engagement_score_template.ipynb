# %%
import os
import math
import pandas as pd
import pytd as td
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate TD client 
client = td.Client(
    apikey='10468/8a7d28932559063ea814146d112ef0d8eff3f3ed',
    endpoint='https://api.treasuredata.com/',
    database='engagement_score',
    default_engine='presto'
)

# %%
raw_base = client.query('''
    select 
        engagement_score,recency,frequency,volume 
    from 
        engagement_score.engagement_score_client 
    limit 
        500000''', client)

df = pd.DataFrame(raw_base['data'], columns=raw_base['columns'])

df.head()
# Out:
#    engagement_score  recency  frequency  volume
# 0          0.602060      -25          1       1
# 1          0.602060      -25          1       1
# 2          0.602060      -25          1       1
# 3          1.176091      -14          1       1
# 4          1.176091      -14          1       1

# %%
plt.figure(figsize=(8,4),dpi=200)
plt.xlabel("engagement_score")
plt.ylabel("population")
plt.hist(df["engagement_score"], bins=60)
plt.show()

# %%
plt.figure(figsize=(8,4),dpi=200)
plt.xlabel("recency")
plt.ylabel("population")
plt.hist(df["recency"], bins=60)
plt.show()

# %%
plt.figure(figsize=(8,4),dpi=200)
plt.xlabel("frequency")
plt.ylabel("population")
#plt.ylim(0, 1000)
plt.hist(df["frequency"], bins=60)
plt.show()

# %%
plt.figure(figsize=(8,4),dpi=200)
plt.xlabel("volume")
plt.ylabel("population")
#plt.ylim(0, 1000)
plt.hist(df["volume"], bins=200)
plt.show()

# %%
plt.figure(figsize=(8,4),dpi=200)
plt.xlabel("frequency")
plt.ylabel("volume")
plt.scatter(df["frequency"], df["volume"])
plt.show()

# %%
plt.figure(figsize=(8,4),dpi=200)
plt.xlabel("recency")
plt.ylabel("frequency")
plt.scatter(df["recency"], df["frequency"])
plt.show()
